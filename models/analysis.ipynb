# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("../data/1400.xlsx")
# data = pd.read_excel("../data/1400.xlsx", sheet_name="Structures-ADMET")
# data = pd.read_excel("../data/35000.xlsx")

# %%
data
# Out:
#               Title  IC50, mmg/ml  CC50-MDCK, mmg/ml             SI  \
# 0       1007-Ya-213           2.7              500.0     185.185185
# 1       1007-Ya-213           0.7              447.0     638.571429
# 2       1008-Ya-187           9.9              144.0      14.545455
# 3       1009-As-106           8.3              500.0      60.240964
# 4       1010-Ya-208          39.4              143.0       3.629442
# ...             ...           ...                ...            ...
# 1463  CHEMBL4251117           7.3              530.6      72.800000
# 1464  CHEMBL4217515           3.8             4733.9    1250.000000
# 1465  CHEMBL4205814           0.3             4733.9   14285.700000
# 1466  CHEMBL4212064           0.7             3662.8    5555.600000
# 1467  CHEMBL4452992           0.1            37646.0  312500.000000
#
#       Molecular weight  Hydrogen bond acceptors  Hydrogen bond donors  \
# 0              195.307                        2                     1
# ...

# %%
data.describe()
# Out:
#        IC50, mmg/ml  CC50-MDCK, mmg/ml            SI  Molecular weight  \
# count   1468.000000        1468.000000  1.444000e+03       1468.000000
# mean      50.277063         186.491530  2.217641e+04        384.739636
# std       92.184768        1009.454293  4.726006e+05        153.164268
# min        0.000010           0.031928  0.000000e+00        110.157000
# 25%        2.500000          30.375000  1.885549e+00        283.049250
# 50%       10.100000          90.400000  5.600000e+00        349.371000
# 75%       49.450000         300.000000  2.832642e+01        446.508000
# max     1000.000000       37646.000000  1.596170e+07       1159.380000
#
#        Hydrogen bond acceptors  Hydrogen bond donors     Polar SA    Pictures
# count              1468.000000           1468.000000  1468.000000  727.000000
# mean                  3.831744              1.333787    81.273215  364.909216
# std                   2.860473              1.803663    54.078778  210.154325
# ...
